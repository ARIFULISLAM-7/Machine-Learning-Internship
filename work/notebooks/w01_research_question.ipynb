# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ARIFULISLAM-7/Machine-Learning-Internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# I chose Refresh / Content Opportunity Scoring because the dataset shows many pages with declining impressions and engagement. Ranking them helps prioritize limited editorial time so reviewers focus on the most promising pages first.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# Decision: Which page to refresh first.
#
# Action: Update metadata or expand content.
#
# Cost: Wasted effort on low‑impact pages or missed recovery opportunities.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# The starter dataset contains 30,000 rows with an average of approximately 5,200 impressions over the 90-day window, demonstrating a substantial volume of pages that can benefit from prioritized content scoring.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd

# Ensure 'content_refresh_anonymized.csv' is uploaded to the Colab environment (e.g., /content/)
df = pd.read_csv('/content/content_refresh_anonymized.csv')
print("Rows:", len(df))
print("Columns:", df.columns.tolist()[:5])
print("Average impressions_90d:", df["impressions_90d"].mean())
# Out:
# Rows: 30000
# Columns: ['content_id', 'client_id', 'search_volume', 'competition', 'competition_level']
# Average impressions_90d: 5200.3663

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# What I can claim: Observed metrics, directional rankings, and decision-support tooling to help target editorial reviews efficiently.
#
# What I will never claim: Causal proof of ranking changes or "predicting Google's algorithm."

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
